# %%
from openai import OpenAI
from minsearch import Index
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase

# %%
# ?load_faq_data
# Out:
# Signature: load_faq_data()
# Docstring: <no docstring>
# File:      ~/Documents/Learning/llm-zoomcamp/llm-zoomcamp-code/ingest.py
# Type:      function

# %%
# ?build_index
# Out:
# Signature: build_index(documents)
# Docstring: <no docstring>
# File:      ~/Documents/Learning/llm-zoomcamp/llm-zoomcamp-code/ingest.py
# Type:      function

# %%
documents = load_faq_data()

index = build_index(documents)

# %%
openai_client = OpenAI()

# %%
??RAGBase.rag
# Out:
# Signature: RAGBase.rag(self, query)
# Docstring: <no docstring>
# Source:
#     def rag(self, query):
#         search_results = self.search(query)
#         prompt = self.build_prompt(query, search_results)
#         answer = self.llm(prompt)
#
#         return answer
# File:      ~/Documents/Learning/llm-zoomcamp/llm-zoomcamp-code/rag_helper.py
# Type:      function

# %%
rag_instance = RAGBase(
    index=index,
    llm_client=openai_client)

# %%
question = "How can I get a certificate ?"

# %%
answer = rag_instance.rag(question)
print(answer)
# Out:
# You can get a certificate only if you finish the course with a live cohort and pass the Capstone project.
#
# A few important points:
# - Self-paced mode does **not** include a certificate.
# - You must submit your project while submissions are still open.
# - You also need to peer-review 3 capstone projects.

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

# %%
assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions=custom_instructions
)

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'You can get a certificate only if you finish the course with a **live cohort**. The course does **not** award certificates for the self-paced mode.\n\nTo be eligible, you need to **pass the Capstone project**. You also need to **peer-review 3 capstones** after submitting your project, which can only be done while the course is running.'

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes — you can still join after the course has started. If you want a certificate, you need to submit your project while submissions are still being accepted.'
