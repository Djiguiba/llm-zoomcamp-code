# %%
from huggingface_hub import login
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer

# %%
load_dotenv()
# Out:
# True

# %%
login()

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %% [markdown]
# ## Embdedding documents

# %%
from ingest import load_faq_data

# %%
documents = load_faq_data()

# %%
texts = []

for doc in documents:
    text = doc['question'] + ' ' + doc['answer']
    texts.append(text)

# %%
from tqdm.auto import tqdm

# %%
batch_size = 50
vectors = []

for i in tqdm(range(0, len(texts), batch_size)):
    batch = texts[i:i+batch_size]
    batch_vectors = model.encode(batch)
    vectors.extend(batch_vectors)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
len(vectors)
# Out:
# 1346

# %% [markdown]
# ## Vector search with sqlitesearch

# %%
from sqlitesearch import VectorSearchIndex

# %%
vindex = VectorSearchIndex(
    keyword_fields=['course'],
    mode='ivf',
    db_path='faq_vectors.db'
)

# %%
vindex.fit(vectors, documents)

# %%
query = "How can I get a certificate ?"
query_vector = model.encode(query)

# %%
results = vindex.search(
    query_vector,
    filter_dict={"course": "llm-zoomcamp"},
    num_results=5
)

# %%
print(results)
# Out:
# [{'id': '69d122f12e', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'Certificate: Can I follow the course in a self-paced mode and get a certificate?', 'answer': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.'}, {'id': '74eb249bbf', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'I just discovered the course. Can I still join?', 'answer': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.'}, {'id': '9f689c185f', 'course': 'llm-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'I missed the first homework - can I st
# ...

# %%
vindex.close()

# %% [markdown]
# ## Reopening the index

# %%
vs_index = VectorSearchIndex(
    keyword_fields=["course"],
    mode='ivf',
    db_path="faq_vectors.db"
)

# %%
query = "How do I run Kafka?"
query_vector = model.encode(query)

# %%
results = vs_index.search(
    query_vector,
    num_results=5
)

# %%
for doc in results:
    print(doc['question'])
    print(doc['answer'])
    print("**************************************")
# Out:
# Java Kafka: How to run producer/consumer/kstreams/etc in terminal
# In the project directory, run:
#
# ```bash
# java -cp build/libs/<jar_name>-1.0-SNAPSHOT.jar:out src/main/java/org/example/JsonProducer.java
# ```
# **************************************
# Java Kafka: When running the producer/consumer/etc java scripts, no results retrieved or no message sent
# For example, when running `JsonConsumer.java`, you might see:
#
# ```
# Consuming form kafka started
#
# RESULTS:::0
#
# RESULTS:::0
#
# RESULTS:::0
# ```
#
# Or when running `JsonProducer.java`, you might encounter:
#
# ```
# Exception in thread "main" java.util.concurrent.ExecutionException: org.apache.kafka.common.errors.SaslAuthenticationException: Authentication failed
# ```
#
# **Solution:**
#
# ...

# %%
vs_index.close()

# %%
import anthropic
from rag_helper import RAGVector

# %%
client = anthropic.Anthropic()

# %%
vector_assistant = RAGVector(
    index=vs_index,
    llm_client=client,
    embedder=model,
    course="data-engineering-zoomcamp",
    model="claude-haiku-4-5"
)

# %%
results = vector_assistant.rag("How do I run Kafka?")

# %%
print(results.content[0].text)
# Out:
# # How to Run Kafka
#
# Based on the context, here are the main ways to run Kafka:
#
# ## For Java Applications
#
# Run the following command in your project directory:
#
# ```bash
# java -cp build/libs/<jar_name>-1.0-SNAPSHOT.jar:out src/main/java/org/example/JsonProducer.java
# ```
#
# Replace `JsonProducer.java` with the specific Kafka component you want to run (e.g., `JsonConsumer.java`, `KStreams`, etc.).
#
# ## For Python Applications
#
# 1. **Create and activate a virtual environment:**
#    - macOS/Linux: `source env/bin/activate`
#    - Windows: `env\Scripts\activate`
#
# 2. **Install required packages:**
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 3. **Ensure Docker is running** before executing your Python file
#
# ## Important Prerequisites
#
# Before running Kafka, make sure:
# - Your Kafka broker Docker container is running
# - If it's not running, use: `docker-compose up -d`
# - Verify containers are running with: `docker ps`
# ...
